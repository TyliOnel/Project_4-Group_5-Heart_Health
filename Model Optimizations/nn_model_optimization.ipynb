# %% [markdown]
# ## Neural Network Model Optimization

# %%
# Importing dependencies
import pandas as pd
from pathlib import Path
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
from tensorflow.keras import metrics
from sqlalchemy import create_engine

# %%
# Connecting to PostgreSQL
engine = create_engine('postgresql://postgres:postgres@localhost:5432/proj4_db')

query = "SELECT * FROM cleaned_data"
df = pd.read_sql(query, engine)
df.head()
# Out:
#    sex  age  education  smokingStatus  cigsPerDay  BPMeds  prevalentStroke  \
# 0  1.0   39          4            0.0           0   False            False
# 1  0.0   46          2            0.0           0   False            False
# 2  1.0   48          1            1.0          20   False            False
# 3  0.0   61          3            1.0          30   False            False
# 4  0.0   46          3            1.0          23   False            False
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0         False     False      195  106.0   70.0  26.97         80       77
# 1         False     False      250  121.0   81.0  28.73         95       76
# 2         False     False      245  127.5   80.0  25.34         75       70
# 3          True     False      225  150.0   95.0  28.58         65      103
# 4         False     False      285  130.0   84.0  23.10         85       85
#
#    CHDRisk
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False

# %% [markdown]
# ## Optimization Attempt 1
# For the first optimization attempt, we drop features with low PCA loadings from our PCA analysis (sex, BPMeds, prevalentStroke, diabetes)

# %%
df_op1 = df.copy()
df_op1.drop(columns=['sex', 'BPMeds', 'prevalentStroke', 'diabetes'], inplace=True)

# %%
# Separating target variables and features
y = df_op1['CHDRisk']
X = df_op1.drop(columns='CHDRisk')

# %%
# Splitting the data into testing and training data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
y_train.value_counts()
# Out:
# CHDRisk
# False    2312
# True      415
# Name: count, dtype: int64

# %%
# Using synthetic minority over-sampling technique to balance the target variable conditions in the training data
smote = SMOTE(random_state=1)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
y_train_resampled.value_counts()
# Out:
# CHDRisk
# False    2312
# True     2312
# Name: count, dtype: int64

# %%
# Scaling the feature variables
scaler = StandardScaler()
X_scaler = scaler.fit(X_train_resampled)

X_train_scaled = X_scaler.transform(X_train_resampled)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Defining original model
number_input_features = X_train.shape[1]

nn = tf.keras.models.Sequential()

# Input layer
nn.add(
    tf.keras.layers.Dense(units=64, input_dim=number_input_features, activation='relu')
)

# Hidden layer 1
nn.add(tf.keras.layers.Dense(units=32, activation='relu'))

# Hidden layer 2
nn.add(tf.keras.layers.Dense(units=16, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Checking the structure of the model
nn.summary()
# Out:
# c:\Users\emily\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,393 (13.25 KB)
#  Trainable params: 3,393 (13.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compiling the model
nn.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy', metrics.Recall()]
)

# %%
# Training model
fit_model = nn.fit(X_train_scaled, y_train_resampled, epochs=100)
# Out:
# Epoch 1/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 2s 967us/step - accuracy: 0.6441 - loss: 0.6291 - recall: 0.5762
# Epoch 2/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.7033 - loss: 0.5620 - recall: 0.7269
# Epoch 3/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.7144 - loss: 0.5569 - recall: 0.7338
# Epoch 4/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.7235 - loss: 0.5401 - recall: 0.7575
# Epoch 5/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.7372 - loss: 0.5248 - recall: 0.7728
# Epoch 6/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.7592 - loss: 0.5117 - recall: 0.7910
# Epoch 7/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.7520 - loss: 0.5002 - recall: 0.7773
# Epoch 8/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.7593 - loss: 0.4913 - recall: 0.7843
# Epoch 9/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.7754 - loss: 0.4696 - recall: 0.8320
# Epoch 10/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.7837 - loss: 0.4699 - recall: 0.8307
# Epoch 11/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.7781 - loss: 0.4690 - recall: 0.8165
# Epoch 12/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.7880 - loss: 0.4433 - recall: 0.8035
# Epoch 13/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.7884 - loss: 0.4486 - recall: 0.8078
# Epoch 14/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7943 - loss: 0.4339 - recall: 0.8337
# Epoch 15/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - accuracy: 0.8151 - loss: 0.4075 - recall: 0.8465
# Epoch 16/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.8179 - loss: 0.3987 - recall: 0.8479
# Epoch 17/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.8157 - loss: 0.4046 - recall: 0.8482
# Epoch 18/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.8373 - loss: 0.3756 - recall: 0.8608
# Epoch 19/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.8346 - loss: 0.3759 - recall: 0.8481
# Epoch 20/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.8386 - loss: 0.3774 - recall: 0.8723
# Epoch 21/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.8314 - loss: 0.3681 - recall: 0.8519
# Epoch 22/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.8469 - loss: 0.3626 - recall: 0.8617
# Epoch 23/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.8513 - loss: 0.3550 - recall: 0.8674
# Epoch 24/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.8534 - loss: 0.3419 - recall: 0.8771
# Epoch 25/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.8648 - loss: 0.3289 - recall: 0.8857
# Epoch 26/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.8755 - loss: 0.3129 - recall: 0.8932
# Epoch 27/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.8677 - loss: 0.3160 - recall: 0.8913
# Epoch 28/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.8576 - loss: 0.3232 - recall: 0.8788
# Epoch 29/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.8696 - loss: 0.3074 - recall: 0.8869
# Epoch 30/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.8643 - loss: 0.3092 - recall: 0.8807
# Epoch 31/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.8785 - loss: 0.2960 - recall: 0.8934
# Epoch 32/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.8819 - loss: 0.2886 - recall: 0.8898
# Epoch 33/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.8798 - loss: 0.2902 - recall: 0.9089
# Epoch 34/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.8807 - loss: 0.2789 - recall: 0.8909
# Epoch 35/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.8869 - loss: 0.2756 - recall: 0.9028
# Epoch 36/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.8934 - loss: 0.2690 - recall: 0.9091
# Epoch 37/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9012 - loss: 0.2582 - recall: 0.9179
# Epoch 38/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 0.8936 - loss: 0.2594 - recall: 0.9113
# Epoch 39/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9034 - loss: 0.2484 - recall: 0.9287
# Epoch 40/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.8990 - loss: 0.2482 - recall: 0.9082
# Epoch 41/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9058 - loss: 0.2411 - recall: 0.9281
# Epoch 42/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.8970 - loss: 0.2590 - recall: 0.9238
# Epoch 43/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.9100 - loss: 0.2369 - recall: 0.9260
# Epoch 44/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.9071 - loss: 0.2386 - recall: 0.9335
# Epoch 45/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.9062 - loss: 0.2324 - recall: 0.9276
# Epoch 46/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - accuracy: 0.9031 - loss: 0.2302 - recall: 0.9127
# Epoch 47/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - accuracy: 0.9195 - loss: 0.2191 - recall: 0.9422
# Epoch 48/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9143 - loss: 0.2218 - recall: 0.9346
# Epoch 49/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.9213 - loss: 0.2123 - recall: 0.9338
# Epoch 50/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.9234 - loss: 0.2053 - recall: 0.9340
# Epoch 51/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.9124 - loss: 0.2133 - recall: 0.9188
# Epoch 52/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.9143 - loss: 0.2152 - recall: 0.9353
# Epoch 53/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.9120 - loss: 0.2196 - recall: 0.9271
# Epoch 54/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.9234 - loss: 0.1949 - recall: 0.9354
# Epoch 55/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9240 - loss: 0.2042 - recall: 0.9487
# Epoch 56/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.9320 - loss: 0.1838 - recall: 0.9421
# Epoch 57/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9325 - loss: 0.1814 - recall: 0.9538
# Epoch 58/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.9298 - loss: 0.1875 - recall: 0.9472
# Epoch 59/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.9320 - loss: 0.1874 - recall: 0.9433
# Epoch 60/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - accuracy: 0.9210 - loss: 0.1938 - recall: 0.9404
# Epoch 61/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - accuracy: 0.9290 - loss: 0.1917 - recall: 0.9464
# Epoch 62/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.9335 - loss: 0.1781 - recall: 0.9508
# Epoch 63/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.9277 - loss: 0.1876 - recall: 0.9432
# Epoch 64/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9325 - loss: 0.1763 - recall: 0.9423
# Epoch 65/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.9440 - loss: 0.1555 - recall: 0.9562
# Epoch 66/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9349 - loss: 0.1750 - recall: 0.9467
# Epoch 67/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9395 - loss: 0.1629 - recall: 0.9498
# Epoch 68/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9406 - loss: 0.1604 - recall: 0.9591
# Epoch 69/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.9435 - loss: 0.1597 - recall: 0.9552
# Epoch 70/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.9387 - loss: 0.1707 - recall: 0.9534
# Epoch 71/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.9457 - loss: 0.1487 - recall: 0.9532
# Epoch 72/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9419 - loss: 0.1609 - recall: 0.9590
# Epoch 73/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.9504 - loss: 0.1430 - recall: 0.9597
# Epoch 74/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.9528 - loss: 0.1364 - recall: 0.9632
# Epoch 75/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9499 - loss: 0.1426 - recall: 0.9640
# Epoch 76/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.9497 - loss: 0.1483 - recall: 0.9538
# Epoch 77/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.9515 - loss: 0.1381 - recall: 0.9711
# Epoch 78/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.9522 - loss: 0.1390 - recall: 0.9661
# Epoch 79/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9521 - loss: 0.1411 - recall: 0.9628
# Epoch 80/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9421 - loss: 0.1477 - recall: 0.9536
# Epoch 81/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.9566 - loss: 0.1310 - recall: 0.9669
# Epoch 82/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9511 - loss: 0.1310 - recall: 0.9588
# Epoch 83/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.9496 - loss: 0.1417 - recall: 0.9657
# Epoch 84/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.9595 - loss: 0.1232 - recall: 0.9704
# Epoch 85/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9553 - loss: 0.1256 - recall: 0.9641
# Epoch 86/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9568 - loss: 0.1206 - recall: 0.9713
# Epoch 87/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.9588 - loss: 0.1176 - recall: 0.9759
# Epoch 88/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9563 - loss: 0.1199 - recall: 0.9655
# Epoch 89/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - accuracy: 0.9561 - loss: 0.1213 - recall: 0.9668
# Epoch 90/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.9615 - loss: 0.1124 - recall: 0.9723
# Epoch 91/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.9582 - loss: 0.1120 - recall: 0.9701
# Epoch 92/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - accuracy: 0.9546 - loss: 0.1214 - recall: 0.9590
# Epoch 93/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.9631 - loss: 0.1080 - recall: 0.9691
# Epoch 94/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.9652 - loss: 0.1049 - recall: 0.9701
# Epoch 95/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.9666 - loss: 0.1046 - recall: 0.9757
# Epoch 96/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9669 - loss: 0.1045 - recall: 0.9727
# Epoch 97/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.9724 - loss: 0.0966 - recall: 0.9796
# Epoch 98/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9723 - loss: 0.0889 - recall: 0.9810
# Epoch 99/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9727 - loss: 0.0899 - recall: 0.9818
# Epoch 100/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.9685 - loss: 0.0959 - recall: 0.9748

# %%
# Evaluate the model using the test data
model_loss, model_accuracy, model_recall = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}, Recall: {model_recall}")
# Out:
# 29/29 - 0s - 7ms/step - accuracy: 0.7033 - loss: 1.4461 - recall: 0.2681
# Loss: 1.446116328239441, Accuracy: 0.7032967209815979, Recall: 0.26811593770980835

# %% [markdown]
# This neural network model was slightly more accurate than the original NN model, however recall was lower.

# %% [markdown]
# ## Optimization Attempt 2
# For the second optimization attempt, we're dropping the binary features with high correlation to other non-binary features (smokingStatus, prevalentHyp, diabetes)

# %%
df_op2 = df.copy()
df_op2.drop(columns=['smokingStatus', 'prevalentHyp', 'diabetes'], inplace=True)

# %%
df_op2.head()
# Out:
#    sex  age  education  cigsPerDay  BPMeds  prevalentStroke  totChol  sysBP  \
# 0  1.0   39          4           0   False            False      195  106.0
# 1  0.0   46          2           0   False            False      250  121.0
# 2  1.0   48          1          20   False            False      245  127.5
# 3  0.0   61          3          30   False            False      225  150.0
# 4  0.0   46          3          23   False            False      285  130.0
#
#    diaBP    BMI  heartRate  glucose  CHDRisk
# 0   70.0  26.97         80       77    False
# 1   81.0  28.73         95       76    False
# 2   80.0  25.34         75       70    False
# 3   95.0  28.58         65      103     True
# 4   84.0  23.10         85       85    False

# %%
# Separating target variables and features
y = df_op2['CHDRisk']
X = df_op2.drop(columns='CHDRisk')

# %%
# Splitting the data into testing and training data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
# Using synthetic minority over-sampling technique to balance the target variable conditions in the training data
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
# Scaling the feature variables
X_scaler = scaler.fit(X_train_resampled)

X_train_scaled = X_scaler.transform(X_train_resampled)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Defining original model
number_input_features = X_train.shape[1]

nn = tf.keras.models.Sequential()

# Input layer
nn.add(
    tf.keras.layers.Dense(units=64, input_dim=number_input_features, activation='relu')
)

# Hidden layer 1
nn.add(tf.keras.layers.Dense(units=32, activation='relu'))

# Hidden layer 2
nn.add(tf.keras.layers.Dense(units=16, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Checking the structure of the model
nn.summary()
# Out:
# c:\Users\emily\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 64)             │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,457 (13.50 KB)
#  Trainable params: 3,457 (13.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compiling the model
nn.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy', metrics.Recall()]
)

# %%
# Training model
fit_model = nn.fit(X_train_scaled, y_train_resampled, epochs=100)
# Out:
# Epoch 1/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 920us/step - accuracy: 0.6219 - loss: 0.6364 - recall_1: 0.7848
# Epoch 2/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.7058 - loss: 0.5688 - recall_1: 0.7165
# Epoch 3/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.7222 - loss: 0.5454 - recall_1: 0.7393
# Epoch 4/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.7389 - loss: 0.5254 - recall_1: 0.7631
# Epoch 5/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.7269 - loss: 0.5234 - recall_1: 0.7396
# Epoch 6/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.7647 - loss: 0.4941 - recall_1: 0.7743
# Epoch 7/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.7726 - loss: 0.4755 - recall_1: 0.7823
# Epoch 8/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.7876 - loss: 0.4596 - recall_1: 0.8024
# Epoch 9/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.7988 - loss: 0.4295 - recall_1: 0.7965
# Epoch 10/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.8131 - loss: 0.4203 - recall_1: 0.8232
# Epoch 11/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.8182 - loss: 0.4017 - recall_1: 0.8347
# Epoch 12/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.8242 - loss: 0.3925 - recall_1: 0.8267
# Epoch 13/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.8451 - loss: 0.3618 - recall_1: 0.8519
# Epoch 14/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.8409 - loss: 0.3556 - recall_1: 0.8504
# Epoch 15/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.8484 - loss: 0.3423 - recall_1: 0.8418
# Epoch 16/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.8531 - loss: 0.3341 - recall_1: 0.8571
# Epoch 17/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.8636 - loss: 0.3210 - recall_1: 0.8724
# Epoch 18/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.8717 - loss: 0.3054 - recall_1: 0.8723
# Epoch 19/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.8673 - loss: 0.3119 - recall_1: 0.8699
# Epoch 20/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.8703 - loss: 0.3085 - recall_1: 0.8687
# Epoch 21/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.8800 - loss: 0.2820 - recall_1: 0.8763
# Epoch 22/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.8846 - loss: 0.2740 - recall_1: 0.8916
# Epoch 23/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.8845 - loss: 0.2779 - recall_1: 0.8873
# Epoch 24/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.8953 - loss: 0.2586 - recall_1: 0.8968
# Epoch 25/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.8895 - loss: 0.2573 - recall_1: 0.8939
# Epoch 26/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.8977 - loss: 0.2545 - recall_1: 0.8906
# Epoch 27/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.9037 - loss: 0.2480 - recall_1: 0.8997
# Epoch 28/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.8959 - loss: 0.2524 - recall_1: 0.9000
# Epoch 29/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.9086 - loss: 0.2312 - recall_1: 0.9024
# Epoch 30/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.9099 - loss: 0.2271 - recall_1: 0.9089
# Epoch 31/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.9051 - loss: 0.2314 - recall_1: 0.9001
# Epoch 32/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9233 - loss: 0.2128 - recall_1: 0.9207
# Epoch 33/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.9258 - loss: 0.2017 - recall_1: 0.9336
# Epoch 34/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.9128 - loss: 0.2176 - recall_1: 0.9273
# Epoch 35/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - accuracy: 0.9129 - loss: 0.2114 - recall_1: 0.9099
# Epoch 36/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.9211 - loss: 0.2034 - recall_1: 0.9144
# Epoch 37/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - accuracy: 0.9209 - loss: 0.1970 - recall_1: 0.9150
# Epoch 38/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.9250 - loss: 0.1936 - recall_1: 0.9270
# Epoch 39/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.9342 - loss: 0.1776 - recall_1: 0.9331
# Epoch 40/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9164 - loss: 0.2054 - recall_1: 0.9184
# Epoch 41/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9250 - loss: 0.1842 - recall_1: 0.9275
# Epoch 42/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9289 - loss: 0.1787 - recall_1: 0.9407
# Epoch 43/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.9339 - loss: 0.1715 - recall_1: 0.9285
# Epoch 44/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.9194 - loss: 0.1971 - recall_1: 0.9406
# Epoch 45/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.9320 - loss: 0.1710 - recall_1: 0.9375
# Epoch 46/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.9386 - loss: 0.1647 - recall_1: 0.9425
# Epoch 47/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.9423 - loss: 0.1582 - recall_1: 0.9489
# Epoch 48/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.9437 - loss: 0.1614 - recall_1: 0.9526
# Epoch 49/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - accuracy: 0.9452 - loss: 0.1551 - recall_1: 0.9430
# Epoch 50/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - accuracy: 0.9359 - loss: 0.1608 - recall_1: 0.9350
# Epoch 51/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.9413 - loss: 0.1499 - recall_1: 0.9477
# Epoch 52/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.9494 - loss: 0.1373 - recall_1: 0.9559
# Epoch 53/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - accuracy: 0.9541 - loss: 0.1370 - recall_1: 0.9582
# Epoch 54/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - accuracy: 0.9400 - loss: 0.1529 - recall_1: 0.9511
# Epoch 55/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.9449 - loss: 0.1389 - recall_1: 0.9520
# Epoch 56/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.9402 - loss: 0.1519 - recall_1: 0.9523
# Epoch 57/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9485 - loss: 0.1300 - recall_1: 0.9473
# Epoch 58/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.9574 - loss: 0.1170 - recall_1: 0.9614
# Epoch 59/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9477 - loss: 0.1314 - recall_1: 0.9462
# Epoch 60/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.9486 - loss: 0.1361 - recall_1: 0.9430
# Epoch 61/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - accuracy: 0.9608 - loss: 0.1123 - recall_1: 0.9623
# Epoch 62/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - accuracy: 0.9540 - loss: 0.1253 - recall_1: 0.9529
# Epoch 63/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9612 - loss: 0.1140 - recall_1: 0.9624
# Epoch 64/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - accuracy: 0.9601 - loss: 0.1150 - recall_1: 0.9594
# Epoch 65/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.9594 - loss: 0.1153 - recall_1: 0.9695
# Epoch 66/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.9579 - loss: 0.1167 - recall_1: 0.9678
# Epoch 67/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.9640 - loss: 0.1065 - recall_1: 0.9709
# Epoch 68/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9634 - loss: 0.1070 - recall_1: 0.9628
# Epoch 69/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.9574 - loss: 0.1163 - recall_1: 0.9603
# Epoch 70/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9662 - loss: 0.1015 - recall_1: 0.9646
# Epoch 71/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9516 - loss: 0.1195 - recall_1: 0.9537
# Epoch 72/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.9640 - loss: 0.1003 - recall_1: 0.9723
# Epoch 73/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.9624 - loss: 0.1038 - recall_1: 0.9636
# Epoch 74/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.9685 - loss: 0.0889 - recall_1: 0.9748
# Epoch 75/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9669 - loss: 0.0942 - recall_1: 0.9732
# Epoch 76/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - accuracy: 0.9568 - loss: 0.1051 - recall_1: 0.9582
# Epoch 77/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - accuracy: 0.9717 - loss: 0.0903 - recall_1: 0.9742
# Epoch 78/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.9685 - loss: 0.0873 - recall_1: 0.9709
# Epoch 79/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.9743 - loss: 0.0791 - recall_1: 0.9762
# Epoch 80/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.9714 - loss: 0.0867 - recall_1: 0.9713
# Epoch 81/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - accuracy: 0.9621 - loss: 0.1019 - recall_1: 0.9618
# Epoch 82/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - accuracy: 0.9714 - loss: 0.0926 - recall_1: 0.9706
# Epoch 83/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.9704 - loss: 0.0829 - recall_1: 0.9738
# Epoch 84/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.9673 - loss: 0.0895 - recall_1: 0.9683
# Epoch 85/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - accuracy: 0.9762 - loss: 0.0724 - recall_1: 0.9796
# Epoch 86/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.9651 - loss: 0.0943 - recall_1: 0.9644
# Epoch 87/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.9710 - loss: 0.0881 - recall_1: 0.9733
# Epoch 88/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.9701 - loss: 0.0912 - recall_1: 0.9720
# Epoch 89/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.9746 - loss: 0.0755 - recall_1: 0.9762
# Epoch 90/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9749 - loss: 0.0742 - recall_1: 0.9778
# Epoch 91/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 0.9745 - loss: 0.0757 - recall_1: 0.9740
# Epoch 92/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.9767 - loss: 0.0694 - recall_1: 0.9823
# Epoch 93/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.9795 - loss: 0.0618 - recall_1: 0.9819
# Epoch 94/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.9796 - loss: 0.0672 - recall_1: 0.9876
# Epoch 95/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.9751 - loss: 0.0718 - recall_1: 0.9789
# Epoch 96/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.9664 - loss: 0.0847 - recall_1: 0.9727
# Epoch 97/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.9791 - loss: 0.0693 - recall_1: 0.9803
# Epoch 98/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.9686 - loss: 0.0935 - recall_1: 0.9683
# Epoch 99/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.9740 - loss: 0.0733 - recall_1: 0.9787
# Epoch 100/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.9823 - loss: 0.0562 - recall_1: 0.9887

# %%
# Evaluate the model using the test data
model_loss, model_accuracy, model_recall = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}, Recall: {model_recall}")
# Out:
# 29/29 - 0s - 8ms/step - accuracy: 0.7319 - loss: 1.6564 - recall_1: 0.2464
# Loss: 1.656411051750183, Accuracy: 0.7318681478500366, Recall: 0.24637681245803833

# %% [markdown]
# This nn model increased in both accuracy and recall from the previous optimization attempt, and is currently the most accurate NN model.

# %% [markdown]
# ## Optimization attempt 3
# In this optimization attempt, we drop the features with the lowest feature importances (as calculated by the RF model): diabetes, BPMeds, and prevalentStroke.

# %%
df_op3 = df.copy()
df_op3.drop(columns=['diabetes', 'BPMeds', 'prevalentStroke'], inplace=True)

# %%
df_op3.head()
# Out:
#    sex  age  education  smokingStatus  cigsPerDay  prevalentHyp  totChol  \
# 0  1.0   39          4            0.0           0         False      195
# 1  0.0   46          2            0.0           0         False      250
# 2  1.0   48          1            1.0          20         False      245
# 3  0.0   61          3            1.0          30          True      225
# 4  0.0   46          3            1.0          23         False      285
#
#    sysBP  diaBP    BMI  heartRate  glucose  CHDRisk
# 0  106.0   70.0  26.97         80       77    False
# 1  121.0   81.0  28.73         95       76    False
# 2  127.5   80.0  25.34         75       70    False
# 3  150.0   95.0  28.58         65      103     True
# 4  130.0   84.0  23.10         85       85    False

# %%
# Separating target variables and features
y = df_op3['CHDRisk']
X = df_op3.drop(columns='CHDRisk')

# %%
# Splitting the data into testing and training data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
# Using synthetic minority over-sampling technique to balance the target variable conditions in the training data
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
# Scaling the feature variables
scaler = StandardScaler()
X_scaler = scaler.fit(X_train_resampled)

X_train_scaled = X_scaler.transform(X_train_resampled)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Defining original model
number_input_features = X_train.shape[1]

nn = tf.keras.models.Sequential()

# Input layer
nn.add(
    tf.keras.layers.Dense(units=64, input_dim=number_input_features, activation='relu')
)

# Hidden layer 1
nn.add(tf.keras.layers.Dense(units=32, activation='relu'))

# Hidden layer 2
nn.add(tf.keras.layers.Dense(units=16, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Checking the structure of the model
nn.summary()
# Out:
# c:\Users\emily\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 64)             │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,457 (13.50 KB)
#  Trainable params: 3,457 (13.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compiling the model
nn.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy', metrics.Recall()]
)

# %%
# Training model
op3_model = nn.fit(X_train_scaled, y_train_resampled, epochs=100)
# Out:
# Epoch 1/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 871us/step - accuracy: 0.6275 - loss: 0.6367 - recall_2: 0.5674
# Epoch 2/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.7202 - loss: 0.5577 - recall_2: 0.7478
# Epoch 3/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - accuracy: 0.7304 - loss: 0.5419 - recall_2: 0.7396
# Epoch 4/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.7388 - loss: 0.5275 - recall_2: 0.7548
# Epoch 5/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.7534 - loss: 0.5046 - recall_2: 0.7806
# Epoch 6/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.7667 - loss: 0.4934 - recall_2: 0.7917
# Epoch 7/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.7719 - loss: 0.4826 - recall_2: 0.8025
# Epoch 8/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.7899 - loss: 0.4551 - recall_2: 0.8101
# Epoch 9/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.8038 - loss: 0.4317 - recall_2: 0.8166
# Epoch 10/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.8050 - loss: 0.4264 - recall_2: 0.8274
# Epoch 11/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.8206 - loss: 0.3979 - recall_2: 0.8288
# Epoch 12/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.8390 - loss: 0.3829 - recall_2: 0.8635
# Epoch 13/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.8328 - loss: 0.3718 - recall_2: 0.8513
# Epoch 14/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.8482 - loss: 0.3557 - recall_2: 0.8511
# Epoch 15/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.8575 - loss: 0.3446 - recall_2: 0.8755
# Epoch 16/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.8597 - loss: 0.3278 - recall_2: 0.8674
# Epoch 17/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.8656 - loss: 0.3219 - recall_2: 0.8684
# Epoch 18/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.8647 - loss: 0.3213 - recall_2: 0.8856
# Epoch 19/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.8736 - loss: 0.3040 - recall_2: 0.8854
# Epoch 20/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - accuracy: 0.8784 - loss: 0.2926 - recall_2: 0.8874
# Epoch 21/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.8880 - loss: 0.2695 - recall_2: 0.9035
# Epoch 22/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.8974 - loss: 0.2600 - recall_2: 0.8951
# Epoch 23/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.8944 - loss: 0.2567 - recall_2: 0.9028
# Epoch 24/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - accuracy: 0.8973 - loss: 0.2585 - recall_2: 0.9106
# Epoch 25/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.9024 - loss: 0.2502 - recall_2: 0.9184
# Epoch 26/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9046 - loss: 0.2528 - recall_2: 0.9112
# Epoch 27/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.8963 - loss: 0.2472 - recall_2: 0.9164
# Epoch 28/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.9101 - loss: 0.2246 - recall_2: 0.9216
# Epoch 29/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.9101 - loss: 0.2273 - recall_2: 0.9196
# Epoch 30/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9219 - loss: 0.2108 - recall_2: 0.9326
# Epoch 31/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - accuracy: 0.9188 - loss: 0.2060 - recall_2: 0.9273
# Epoch 32/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.9254 - loss: 0.2068 - recall_2: 0.9425
# Epoch 33/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - accuracy: 0.9188 - loss: 0.2007 - recall_2: 0.9292
# Epoch 34/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.9196 - loss: 0.1996 - recall_2: 0.9291
# Epoch 35/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9299 - loss: 0.1900 - recall_2: 0.9391
# Epoch 36/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9335 - loss: 0.1795 - recall_2: 0.9439
# Epoch 37/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9366 - loss: 0.1724 - recall_2: 0.9468
# Epoch 38/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.9308 - loss: 0.1856 - recall_2: 0.9424
# Epoch 39/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.9149 - loss: 0.1961 - recall_2: 0.9312
# Epoch 40/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9342 - loss: 0.1781 - recall_2: 0.9418
# Epoch 41/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9246 - loss: 0.1849 - recall_2: 0.9321
# Epoch 42/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.9307 - loss: 0.1716 - recall_2: 0.9402
# Epoch 43/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.9396 - loss: 0.1704 - recall_2: 0.9493
# Epoch 44/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.9339 - loss: 0.1713 - recall_2: 0.9356
# Epoch 45/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.9321 - loss: 0.1723 - recall_2: 0.9513
# Epoch 46/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - accuracy: 0.9493 - loss: 0.1480 - recall_2: 0.9608
# Epoch 47/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.9475 - loss: 0.1497 - recall_2: 0.9558
# Epoch 48/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.9419 - loss: 0.1491 - recall_2: 0.9445
# Epoch 49/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.9472 - loss: 0.1443 - recall_2: 0.9550
# Epoch 50/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.9399 - loss: 0.1598 - recall_2: 0.9451
# Epoch 51/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.9500 - loss: 0.1354 - recall_2: 0.9626
# Epoch 52/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.9420 - loss: 0.1463 - recall_2: 0.9514
# Epoch 53/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.9519 - loss: 0.1289 - recall_2: 0.9603
# Epoch 54/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.9552 - loss: 0.1292 - recall_2: 0.9685
# Epoch 55/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.9488 - loss: 0.1375 - recall_2: 0.9575
# Epoch 56/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.9546 - loss: 0.1265 - recall_2: 0.9644
# Epoch 57/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - accuracy: 0.9594 - loss: 0.1213 - recall_2: 0.9674
# Epoch 58/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.9638 - loss: 0.1166 - recall_2: 0.9731
# Epoch 59/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9518 - loss: 0.1236 - recall_2: 0.9571
# Epoch 60/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.9579 - loss: 0.1103 - recall_2: 0.9592
# Epoch 61/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9558 - loss: 0.1161 - recall_2: 0.9641
# Epoch 62/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.9597 - loss: 0.1147 - recall_2: 0.9716
# Epoch 63/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.9632 - loss: 0.1106 - recall_2: 0.9717
# Epoch 64/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.9607 - loss: 0.1095 - recall_2: 0.9702
# Epoch 65/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.9558 - loss: 0.1178 - recall_2: 0.9567
# Epoch 66/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.9602 - loss: 0.1127 - recall_2: 0.9616
# Epoch 67/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.9632 - loss: 0.1030 - recall_2: 0.9695
# Epoch 68/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.9585 - loss: 0.1119 - recall_2: 0.9698
# Epoch 69/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.9744 - loss: 0.0849 - recall_2: 0.9787
# Epoch 70/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - accuracy: 0.9638 - loss: 0.0963 - recall_2: 0.9691
# Epoch 71/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - accuracy: 0.9647 - loss: 0.0982 - recall_2: 0.9729
# Epoch 72/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step - accuracy: 0.9598 - loss: 0.0948 - recall_2: 0.9708
# Epoch 73/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - accuracy: 0.9640 - loss: 0.1009 - recall_2: 0.9661
# Epoch 74/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - accuracy: 0.9620 - loss: 0.1020 - recall_2: 0.9717
# Epoch 75/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - accuracy: 0.9661 - loss: 0.0882 - recall_2: 0.9734
# Epoch 76/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.9642 - loss: 0.0925 - recall_2: 0.9655
# Epoch 77/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.9735 - loss: 0.0823 - recall_2: 0.9790
# Epoch 78/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - accuracy: 0.9687 - loss: 0.0838 - recall_2: 0.9723
# Epoch 79/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9753 - loss: 0.0733 - recall_2: 0.9814
# Epoch 80/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - accuracy: 0.9696 - loss: 0.0872 - recall_2: 0.9796
# Epoch 81/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step - accuracy: 0.9744 - loss: 0.0805 - recall_2: 0.9785
# Epoch 82/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - accuracy: 0.9750 - loss: 0.0704 - recall_2: 0.9768
# Epoch 83/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - accuracy: 0.9685 - loss: 0.0782 - recall_2: 0.9700
# Epoch 84/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.9766 - loss: 0.0750 - recall_2: 0.9809
# Epoch 85/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.9758 - loss: 0.0725 - recall_2: 0.9805
# Epoch 86/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.9783 - loss: 0.0709 - recall_2: 0.9827
# Epoch 87/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.9789 - loss: 0.0701 - recall_2: 0.9841
# Epoch 88/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.9810 - loss: 0.0603 - recall_2: 0.9853
# Epoch 89/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - accuracy: 0.9740 - loss: 0.0771 - recall_2: 0.9780
# Epoch 90/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - accuracy: 0.9783 - loss: 0.0672 - recall_2: 0.9839
# Epoch 91/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - accuracy: 0.9766 - loss: 0.0721 - recall_2: 0.9813
# Epoch 92/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - accuracy: 0.9765 - loss: 0.0673 - recall_2: 0.9794
# Epoch 93/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step - accuracy: 0.9745 - loss: 0.0704 - recall_2: 0.9776
# Epoch 94/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - accuracy: 0.9814 - loss: 0.0555 - recall_2: 0.9831
# Epoch 95/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - accuracy: 0.9771 - loss: 0.0664 - recall_2: 0.9832
# Epoch 96/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - accuracy: 0.9819 - loss: 0.0605 - recall_2: 0.9871
# Epoch 97/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - accuracy: 0.9815 - loss: 0.0537 - recall_2: 0.9843
# Epoch 98/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.9811 - loss: 0.0564 - recall_2: 0.9840
# Epoch 99/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.9820 - loss: 0.0569 - recall_2: 0.9869
# Epoch 100/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.9835 - loss: 0.0532 - recall_2: 0.9887

# %%
# Evaluate the model using the test data
model_loss, model_accuracy, model_recall = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}, Recall: {model_recall}")
# Out:
# 29/29 - 0s - 8ms/step - accuracy: 0.7319 - loss: 1.5531 - recall_2: 0.2971
# Loss: 1.5530589818954468, Accuracy: 0.7318681478500366, Recall: 0.2971014380455017

# %% [markdown]
# ## Optimization Attempt 4
# In this optimization attempt, we use Mean Aerterial Pressure (MAP) in place of systolic and diasystolic pressure (as calculated in our data cleaning)

# %%
# Connecting to PostgreSQL
engine = create_engine('postgresql://postgres:postgres@localhost:5432/proj4_db')

query = "SELECT * FROM cleaned_data_map"
df_map = pd.read_sql(query, engine)
df_map.head()
# Out:
#    sex  age  education  smokingStatus  cigsPerDay  BPMeds  prevalentStroke  \
# 0  1.0   39          4            0.0           0   False            False
# 1  0.0   46          2            0.0           0   False            False
# 2  1.0   48          1            1.0          20   False            False
# 3  0.0   61          3            1.0          30   False            False
# 4  0.0   46          3            1.0          23   False            False
#
#    prevalentHyp  diabetes  totChol    BMI  heartRate  glucose  CHDRisk  \
# 0         False     False      195  26.97         80       77    False
# 1         False     False      250  28.73         95       76    False
# 2         False     False      245  25.34         75       70    False
# 3          True     False      225  28.58         65      103     True
# 4         False     False      285  23.10         85       85    False
#
#           MAP
# 0   82.000000
# 1   94.333333
# 2   95.833333
# 3  113.333333
# 4   99.333333

# %%
# Separating target variables and features
y = df_map['CHDRisk']
X = df_map.drop(columns='CHDRisk')

# %%
# Splitting the data into testing and training data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
# Using synthetic minority over-sampling technique to balance the target variable conditions in the training data
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
# Scaling the feature variables
X_scaler = scaler.fit(X_train_resampled)

X_train_scaled = X_scaler.transform(X_train_resampled)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Defining original model
number_input_features = X_train.shape[1]

nn = tf.keras.models.Sequential()

# Input layer
nn.add(
    tf.keras.layers.Dense(units=64, input_dim=number_input_features, activation='relu')
)

# Hidden layer 1
nn.add(tf.keras.layers.Dense(units=32, activation='relu'))

# Hidden layer 2
nn.add(tf.keras.layers.Dense(units=16, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Checking the structure of the model
nn.summary()
# Out:
# c:\Users\emily\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 64)             │           960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,585 (14.00 KB)
#  Trainable params: 3,585 (14.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compiling the model
nn.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy', metrics.Recall()]
)

# %%
# Training model
fit_model = nn.fit(X_train_scaled, y_train_resampled, epochs=100)
# Out:
# Epoch 1/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 2s 912us/step - accuracy: 0.6356 - loss: 0.6227 - recall_3: 0.5970
# Epoch 2/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - accuracy: 0.7201 - loss: 0.5534 - recall_3: 0.7468
# Epoch 3/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step - accuracy: 0.7328 - loss: 0.5373 - recall_3: 0.7614
# Epoch 4/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - accuracy: 0.7423 - loss: 0.5135 - recall_3: 0.7830
# Epoch 5/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - accuracy: 0.7638 - loss: 0.4947 - recall_3: 0.7842
# Epoch 6/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.7691 - loss: 0.4768 - recall_3: 0.7837
# Epoch 7/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - accuracy: 0.7827 - loss: 0.4605 - recall_3: 0.7846
# Epoch 8/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - accuracy: 0.7991 - loss: 0.4431 - recall_3: 0.8175
# Epoch 9/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - accuracy: 0.8155 - loss: 0.4164 - recall_3: 0.8110
# Epoch 10/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - accuracy: 0.8132 - loss: 0.4112 - recall_3: 0.8193
# Epoch 11/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - accuracy: 0.8204 - loss: 0.3986 - recall_3: 0.8237
# Epoch 12/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - accuracy: 0.8280 - loss: 0.3735 - recall_3: 0.8207
# Epoch 13/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - accuracy: 0.8321 - loss: 0.3699 - recall_3: 0.8251
# Epoch 14/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step - accuracy: 0.8421 - loss: 0.3553 - recall_3: 0.8242
# Epoch 15/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - accuracy: 0.8469 - loss: 0.3348 - recall_3: 0.8452
# Epoch 16/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - accuracy: 0.8616 - loss: 0.3234 - recall_3: 0.8584
# Epoch 17/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - accuracy: 0.8687 - loss: 0.3104 - recall_3: 0.8598
# Epoch 18/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.8633 - loss: 0.3043 - recall_3: 0.8467
# Epoch 19/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.8708 - loss: 0.3012 - recall_3: 0.8786
# Epoch 20/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.8852 - loss: 0.2752 - recall_3: 0.8891
# Epoch 21/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.8822 - loss: 0.2810 - recall_3: 0.8892
# Epoch 22/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.8835 - loss: 0.2664 - recall_3: 0.8786
# Epoch 23/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - accuracy: 0.8887 - loss: 0.2726 - recall_3: 0.8887
# Epoch 24/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 0.8867 - loss: 0.2695 - recall_3: 0.8750
# Epoch 25/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.9052 - loss: 0.2484 - recall_3: 0.8990
# Epoch 26/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.8977 - loss: 0.2482 - recall_3: 0.8967
# Epoch 27/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.8976 - loss: 0.2487 - recall_3: 0.8933
# Epoch 28/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.8979 - loss: 0.2410 - recall_3: 0.8959
# Epoch 29/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.9086 - loss: 0.2227 - recall_3: 0.9029
# Epoch 30/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9139 - loss: 0.2228 - recall_3: 0.9226
# Epoch 31/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.9221 - loss: 0.2137 - recall_3: 0.9210
# Epoch 32/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.9222 - loss: 0.2133 - recall_3: 0.9172
# Epoch 33/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9116 - loss: 0.2120 - recall_3: 0.9117
# Epoch 34/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - accuracy: 0.9077 - loss: 0.2156 - recall_3: 0.9044
# Epoch 35/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.9271 - loss: 0.1971 - recall_3: 0.9317
# Epoch 36/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.9278 - loss: 0.1892 - recall_3: 0.9299
# Epoch 37/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.9265 - loss: 0.1931 - recall_3: 0.9227
# Epoch 38/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.9333 - loss: 0.1732 - recall_3: 0.9341
# Epoch 39/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.9359 - loss: 0.1687 - recall_3: 0.9386
# Epoch 40/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9299 - loss: 0.1832 - recall_3: 0.9291
# Epoch 41/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9207 - loss: 0.1863 - recall_3: 0.9232
# Epoch 42/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9292 - loss: 0.1723 - recall_3: 0.9266
# Epoch 43/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.9333 - loss: 0.1741 - recall_3: 0.9183
# Epoch 44/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.9396 - loss: 0.1635 - recall_3: 0.9455
# Epoch 45/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.9271 - loss: 0.1751 - recall_3: 0.9310
# Epoch 46/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9421 - loss: 0.1495 - recall_3: 0.9425
# Epoch 47/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.9434 - loss: 0.1547 - recall_3: 0.9388
# Epoch 48/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9444 - loss: 0.1519 - recall_3: 0.9468
# Epoch 49/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.9455 - loss: 0.1473 - recall_3: 0.9422
# Epoch 50/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.9432 - loss: 0.1489 - recall_3: 0.9386
# Epoch 51/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.9497 - loss: 0.1384 - recall_3: 0.9545
# Epoch 52/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.9413 - loss: 0.1507 - recall_3: 0.9461
# Epoch 53/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.9429 - loss: 0.1410 - recall_3: 0.9462
# Epoch 54/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9527 - loss: 0.1262 - recall_3: 0.9501
# Epoch 55/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.9450 - loss: 0.1409 - recall_3: 0.9541
# Epoch 56/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.9480 - loss: 0.1343 - recall_3: 0.9490
# Epoch 57/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.9572 - loss: 0.1221 - recall_3: 0.9605
# Epoch 58/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9536 - loss: 0.1286 - recall_3: 0.9558
# Epoch 59/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9572 - loss: 0.1220 - recall_3: 0.9549
# Epoch 60/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9527 - loss: 0.1190 - recall_3: 0.9525
# Epoch 61/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.9582 - loss: 0.1205 - recall_3: 0.9548
# Epoch 62/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.9591 - loss: 0.1206 - recall_3: 0.9620
# Epoch 63/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.9618 - loss: 0.1129 - recall_3: 0.9662
# Epoch 64/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.9591 - loss: 0.1099 - recall_3: 0.9689
# Epoch 65/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.9591 - loss: 0.1104 - recall_3: 0.9608
# Epoch 66/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9639 - loss: 0.0995 - recall_3: 0.9663
# Epoch 67/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.9550 - loss: 0.1241 - recall_3: 0.9551
# Epoch 68/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9657 - loss: 0.1038 - recall_3: 0.9721
# Epoch 69/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9573 - loss: 0.1168 - recall_3: 0.9620
# Epoch 70/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9651 - loss: 0.1048 - recall_3: 0.9677
# Epoch 71/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9689 - loss: 0.0931 - recall_3: 0.9726
# Epoch 72/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9613 - loss: 0.1087 - recall_3: 0.9642
# Epoch 73/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.9722 - loss: 0.0824 - recall_3: 0.9731
# Epoch 74/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.9693 - loss: 0.0864 - recall_3: 0.9678
# Epoch 75/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - accuracy: 0.9684 - loss: 0.0913 - recall_3: 0.9674
# Epoch 76/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.9699 - loss: 0.0869 - recall_3: 0.9693
# Epoch 77/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.9655 - loss: 0.0912 - recall_3: 0.9668
# Epoch 78/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.9747 - loss: 0.0791 - recall_3: 0.9733
# Epoch 79/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - accuracy: 0.9712 - loss: 0.0886 - recall_3: 0.9733
# Epoch 80/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - accuracy: 0.9665 - loss: 0.0964 - recall_3: 0.9651
# Epoch 81/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9764 - loss: 0.0760 - recall_3: 0.9815
# Epoch 82/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.9761 - loss: 0.0751 - recall_3: 0.9780
# Epoch 83/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - accuracy: 0.9587 - loss: 0.1358 - recall_3: 0.9645
# Epoch 84/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.9752 - loss: 0.0737 - recall_3: 0.9755
# Epoch 85/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - accuracy: 0.9723 - loss: 0.0797 - recall_3: 0.9728
# Epoch 86/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.9751 - loss: 0.0722 - recall_3: 0.9728
# Epoch 87/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.9727 - loss: 0.0834 - recall_3: 0.9810
# Epoch 88/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 0.9720 - loss: 0.0790 - recall_3: 0.9714
# Epoch 89/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.9698 - loss: 0.0801 - recall_3: 0.9671
# Epoch 90/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.9666 - loss: 0.0816 - recall_3: 0.9661
# Epoch 91/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.9772 - loss: 0.0709 - recall_3: 0.9780
# Epoch 92/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - accuracy: 0.9835 - loss: 0.0616 - recall_3: 0.9846
# Epoch 93/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - accuracy: 0.9753 - loss: 0.0668 - recall_3: 0.9793
# Epoch 94/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9774 - loss: 0.0667 - recall_3: 0.9806
# Epoch 95/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - accuracy: 0.9591 - loss: 0.0925 - recall_3: 0.9552
# Epoch 96/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.9808 - loss: 0.0583 - recall_3: 0.9845
# Epoch 97/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.9810 - loss: 0.0600 - recall_3: 0.9819
# Epoch 98/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9770 - loss: 0.0615 - recall_3: 0.9798
# Epoch 99/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.9721 - loss: 0.0724 - recall_3: 0.9667
# Epoch 100/100
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - accuracy: 0.9848 - loss: 0.0524 - recall_3: 0.9896

# %%
# Evaluate the model using the test data
model_loss, model_accuracy, model_recall = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}, Recall: {model_recall}")
# Out:
# 29/29 - 0s - 7ms/step - accuracy: 0.7275 - loss: 1.5690 - recall_3: 0.2464
# Loss: 1.5689667463302612, Accuracy: 0.7274725437164307, Recall: 0.24637681245803833
